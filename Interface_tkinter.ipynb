# %% [markdown]
# # Interface Graphique Tkinter

# %%
import tkinter as tk

# %%
from tkinter import *
from tkinter import ttk
from PIL import ImageTk, Image
from tkinter.filedialog import askopenfilename
import tkinter.font as font
import pandas as pd
import os


#def textevar():
    #if ma_variable.get() == "DarkVador":
     #   label['text']="Bienvenue mon maître"
    #else:
     #   label['text']="Réessayer"
        
def Readme():
    Read="Voici les prémices d'une interface graphique tkinter."+"\n"+"Elle comprend un menu permettant d'ouvrir des images(png,jpeg)."+"\n"+"Par la suite on pourra implémenter des méthodes pour traiter ses images."
    return Read


def popup():
    
    popup = Tk()
    popup.title("Projet_de_Recherche")
    popup['bg']='grey'
    label_popup = Label(popup, text='Readme',font=("Verdana",10))
    label_popup.pack()
    bouton_popup = Button(popup, text=Readme(), command = popup.destroy)
    bouton_popup.pack()
    popup.mainloop()
    
def traitement():
    
    popimage = Tk()
    popimage.title("Projet_de_Recherche")
    popimage['bg']='grey'
    chemin_fichier = askopenfilename(filetypes=[('PNG', '*.png'), ('JPEG', '*.jpeg')])
    photo = PhotoImage(file=chemin_fichier)
    label_popimage= Label(popimage,text="Voici l'image selectionné ", font=("Verdana",10),image=photo)
    label_popimage.pack()
    
    #if chemin_fichier.endswith('.csv'):
     #   df = pd.read_csv(chemin_fichier)
    #else:
     #   df = pd.read_excel(chemin_fichier, engine='openpyxl')
    #chemin_dossier = os.path.dirname(chemin_fichier)
    #if "données_modifiées.xlsx" in os.listdir(chemin_dossier):
     #   popupmsg("Il y a déjà un fichier nommé 'données_modifiées.xlsx' dans le dossier, veuillez renommer ce fichier pour que le programme puisse en générer un nouveau.")
    #else :
     #   df.to_excel(str(chemin_dossier) + "\\" + "données_modifiées.xlsx", index=False)
      #  popupmsg("Votre fichier excel est généré =) Vous pouvez le trouver dans le même dossier que le fichier excel initial." + "\n" + "\n" + "A bientôt!" + "\n")
        

root = Tk()
root.geometry('400x400')
root.title('Projet_de_Recherche')
root['bg']='grey'

root.minsize(400,400)
root.maxsize(400,400)

root.resizable(height=True,width=True)
        
        
mon_menu = Menu(root)

fichier = Menu(mon_menu,tearoff=0)
fichier.add_command(label="Ouvrir",command=traitement)
fichier.add_command(label="Readme",command=popup)
fichier.add_command(label="Quitter",command=root.destroy)

options = Menu(mon_menu,tearoff=0)
options.add_command(label="Modification")

mon_menu.add_cascade(label="Fichier",menu=fichier)
#mon_menu.add_cascade(label="Options",menu=options)

root.config(menu=mon_menu)

#ma_variable=StringVar()

boite = Frame(root)
boite.grid()


#entree=Entry(boite,textvariable=ma_variable)
#entree.pack()
#bouton=Button(boite,text="Valider",command=textevar)
#bouton.pack()

label =Label(boite,text='Choisir une image',font=("Verdana",10))
label.pack()
bouton1=Button(boite,text="Ouvrir",font=("Verdana",10),command=traitement)
bouton1.pack(side = BOTTOM)

boite.pack(expand=YES)

label_image=Label(root,text="Image par défaut : ",font=("Verdana",10))
label_image.pack()


photo = PhotoImage(file="C:/Users/pypar/Documents/M1 MMAA/Semestre 8/ProjetDeRecherche/Image/Foot.png")
label= Label(root,image=photo)
label.pack(expand=1)



root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pypar\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\pypar\AppData\Local\Temp\ipykernel_78804\2434760468.py", line 39, in traitement
#     label_popimage= Label(popimage,text="Voici l'image selectionné ", font=("Verdana",10),image=photo)
#   File "C:\Users\pypar\anaconda3\lib\tkinter\__init__.py", line 3148, in __init__
#     Widget.__init__(self, master, 'label', cnf, kw)
#   File "C:\Users\pypar\anaconda3\lib\tkinter\__init__.py", line 2572, in __init__
#     self.tk.call(
# _tkinter.TclError: image "pyimage54" doesn't exist
